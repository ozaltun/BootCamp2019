# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pydataset import data

# %% [markdown]
# ## Problem 1

# %%
titles = ['Titanic', 'Arbuthnot']
datasets = {i:data(i) for i in titles}

# %%
[print(i, '\n', datasets[i].info()) for i in titles]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 1 to 32
# Data columns (total 5 columns):
# Class       32 non-null object
# Sex         32 non-null object
# Age         32 non-null object
# Survived    32 non-null object
# Freq        32 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 1.5+ KB
# Titanic
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 1 to 82
# Data columns (total 7 columns):
# Year         82 non-null int64
# Males        82 non-null int64
# Females      82 non-null int64
# Plague       82 non-null int64
# Mortality    82 non-null int64
# Ratio        82 non-null float64
# Total        82 non-null float64
# dtypes: float64(2), int64(5)
# memory usage: 5.1 KB
# Arbuthnot
#  None
# [None, None]

# %% [markdown]
# ### Titanic

# %%
titanic = datasets['Titanic'][datasets['Titanic'].Freq != 0]

# %%
titanic.groupby('Sex').sum().plot(kind='barh')
titanic.groupby('Class').sum().plot(kind='barh')
titanic.groupby('Age').sum().plot(kind='barh')
titanic.groupby('Survived').sum().plot(kind='barh')
titanic.groupby('Age').sum().plot(kind='barh')

# %% [markdown]
# ## Problem 3

# %%
 
#build toy data for SQL operations
name = ['Mylan', 'Regan', 'Justin', 'Jess', 'Jason', 'Remi', 'Matt', 'Alexander', 'JeanMarie']
sex = ['M', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'F']
age = [20, 21, 18, 22, 19, 20, 20, 19, 20]
rank = ['Sp', 'Se', 'Fr', 'Se', 'Sp', 'J', 'J', 'J', 'Se']
ID = range(9)
aid = ['y', 'n', 'n', 'y', 'n', 'n', 'n', 'y', 'n']
GPA = [3.8, 3.5, 3.0, 3.9, 2.8, 2.9, 3.8, 3.4, 3.7]
mathID = [0, 1, 5, 6, 3]
mathGd = [4.0, 3.0, 3.5, 3.0, 4.0]
major = ['y', 'n', 'y', 'n', 'n']
studentInfo = pd.DataFrame({'ID': ID, 'Name': name, 'Sex': sex, 'Age': age,'Class': rank})
otherInfo = pd.DataFrame({'ID': ID, 'GPA': GPA, 'Financial_Aid': aid})
mathInfo = pd.DataFrame({'ID': mathID, 'Grade': mathGd, 'Math_Major': major})

# %%
studentInfo[(studentInfo.Age >19) & (studentInfo.Sex == 'M')]
# Out:
#    ID   Name Sex  Age Class
# 0   0  Mylan   M   20    Sp
# 6   6   Matt   M   20     J

# %% [markdown]
# ## Problem 4

# %%
pd.merge(studentInfo, mathInfo,  on ='ID', how='outer')[['ID', 'Age', 'Grade']]
# Out:
#    ID  Age  Grade
# 0   0   20    4.0
# 1   1   21    3.0
# 2   2   18    NaN
# 3   3   22    4.0
# 4   4   19    NaN
# 5   5   20    3.5
# 6   6   20    3.0
# 7   7   19    NaN
# 8   8   20    NaN
